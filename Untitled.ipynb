# %%
import pandas as pd

# %% [markdown]
# # a. Сравнение производительности ArrayLinst и LinkedList

# %%
df = pd.read_csv("./report.csv", sep=',')
print(df)
# Out:
#                                 test        class       N        time
# 0      ArrayList vs LinkedList (add)    ArrayList   10000    13779642
# 1      ArrayList vs LinkedList (add)    ArrayList   20000   193262958
# 2      ArrayList vs LinkedList (add)    ArrayList   30000   232357638
# 3      ArrayList vs LinkedList (add)    ArrayList   40000   349033020
# 4      ArrayList vs LinkedList (add)    ArrayList   50000   502111876
# 5      ArrayList vs LinkedList (add)    ArrayList   60000   620353570
# 6      ArrayList vs LinkedList (add)    ArrayList   70000   902579587
# 7      ArrayList vs LinkedList (add)    ArrayList   80000  1186903210
# 8      ArrayList vs LinkedList (add)    ArrayList   90000  1476736750
# 9      ArrayList vs LinkedList (add)    ArrayList  100000  1735537931
# 10     ArrayList vs LinkedList (add)   LinkedList   10000    84040255
# 11     ArrayList vs LinkedList (add)   LinkedList   20000   255655747
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
dsInsert = df.loc[df['test'] == 'ArrayList vs LinkedList (add)']
dsGet = df.loc[df['test'] == 'ArrayList vs LinkedList (get)']
dsIndexOf = df.loc[df['test'] == 'ArrayList vs LinkedList (indexOf)']
dsRemove = df.loc[df['test'] == 'ArrayList vs LinkedList (remove)']
dsMix = df.loc[df['test'] == 'ArrayList vs LinkedList (mix)']

# %%
dsInsertArrayList
# Out:
#                              test        class       N        time
# 0   ArrayList vs LinkedList (add)    ArrayList   10000    13779642
# 1   ArrayList vs LinkedList (add)    ArrayList   20000   193262958
# 2   ArrayList vs LinkedList (add)    ArrayList   30000   232357638
# 3   ArrayList vs LinkedList (add)    ArrayList   40000   349033020
# 4   ArrayList vs LinkedList (add)    ArrayList   50000   502111876
# 5   ArrayList vs LinkedList (add)    ArrayList   60000   620353570
# 6   ArrayList vs LinkedList (add)    ArrayList   70000   902579587
# 7   ArrayList vs LinkedList (add)    ArrayList   80000  1186903210
# 8   ArrayList vs LinkedList (add)    ArrayList   90000  1476736750
# 9   ArrayList vs LinkedList (add)    ArrayList  100000  1735537931
# 10  ArrayList vs LinkedList (add)   LinkedList   10000    84040255
# 11  ArrayList vs LinkedList (add)   LinkedList   20000   255655747
# 12  ArrayList vs LinkedList (add)   LinkedList   30000   382369134
# ...

# %%
dsInsertArrayList
# Out:
# Empty DataFrame
# Columns: [test,  class,  N,  time]
# Index: []

# %% [markdown]
# ## Вставка в произвольное место

# %%
df.loc[df['test'] == 'ArrayList vs LinkedList (add)']
dsInsertArrayList=dsInsert.loc[dsInsert[' class']==' ArrayList']
dsInsertLinkedList=dsInsert.loc[dsInsert[' class']==' LinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsInsertArrayList[First], dsInsertArrayList[Second] / 100, label = 'Insert ArrayList')
plt.plot(dsInsertLinkedList[First], dsInsertLinkedList[Second] / 100, label = 'Insert LinkedList')
plt.title('ArrayList vs LinkedList (add)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('ArraylistAdd.png')
pass

# %% [markdown]
# ## Доступ к элементу

# %%
dsGetArrayList=dsGet.loc[dsGet[' class']==' ArrayList']
dsGetLinkedList=dsGet.loc[dsGet[' class']==' LinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsGetArrayList[First], dsGetArrayList[Second] , label = 'get ArrayList')
plt.plot(dsGetLinkedList[First], dsGetLinkedList[Second] , label = 'get LinkedList')
plt.title('ArrayList vs LinkedList (get)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('ArraylistGet.png')
pass

# %% [markdown]
# ## Поиск

# %%
dsIndexOfArrayList=dsIndexOf.loc[dsIndexOf[' class']==' ArrayList']
dsIndexOfLinkedList=dsIndexOf.loc[dsIndexOf[' class']==' LinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsIndexOfArrayList[First], dsIndexOfArrayList[Second] , label = 'IndexOf ArrayList')
plt.plot(dsIndexOfLinkedList[First], dsIndexOfLinkedList[Second] , label = 'IndexOf LinkedList')
plt.title('ArrayList vs LinkedList (IndexOf)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('ArraylistIndexof.png')
pass

# %% [markdown]
# ## Удаление

# %%
dsRemoveArrayList=dsRemove.loc[dsRemove[' class']==' ArrayList']
dsRemoveLinkedList=dsRemove.loc[dsRemove[' class']==' LinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsRemoveArrayList[First], dsRemoveArrayList[Second] , label = 'Remove ArrayList')
plt.plot(dsRemoveLinkedList[First], dsRemoveLinkedList[Second] , label = 'Remove LinkedList')
plt.title('ArrayList vs LinkedList (Remove)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('ArraylistRemove.png')
pass

# %% [markdown]
# ## Амортизированная оценка

# %%
dsMixArrayList=dsMix.loc[dsMix[' class']==' ArrayList']
dsMixLinkedList=dsMix.loc[dsMix[' class']==' LinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsMixArrayList[First], dsMixArrayList[Second] , label = 'Mix ArrayList')
plt.plot(dsMixLinkedList[First], dsMixLinkedList[Second] , label = 'Mix LinkedList')
plt.title('ArrayList vs LinkedList (Mix)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('ArraylistMix.png')
pass

# %% [markdown]
# ## Вывод
# ArrayList почти всегда быстрей, но может хранить не больше 2147483648 элементов. Для огромных списков лучше использовать LinkedList.

# %% [markdown]
# # b. Сравнение HashSet, LinkedHashSet, TreeSet.

# %%
df = pd.read_csv("./report_set.csv", sep=',')
print(df)
dsAdd=df.loc[df['test'] == 'add']
dsContains=df.loc[df['test'] == 'contains']
dsRemove=df.loc[df['test'] == 'remove']
dsMix=df.loc[df['test'] == 'mix']
# Out:
#     test           class       N      time
# 0    add         HashSet   10000   3258488
# 1    add         HashSet   20000  10533408
# 2    add         HashSet   30000  14267874
# 3    add         HashSet   40000  18529430
# 4    add         HashSet   50000  25492847
# 5    add         HashSet   60000  30770055
# 6    add         HashSet   70000  35296925
# 7    add         HashSet   80000  38842722
# 8    add         HashSet   90000  42629333
# 9    add         HashSet  100000  48099731
# 10   add   LinkedHashSet   10000   2278825
# 11   add   LinkedHashSet   20000   8349347
# 12   add   LinkedHashSet   30000  11184647
# 13   add   LinkedHashSet   40000  14399114
# 14   add   LinkedHashSet   50000  20153690
# 15   add   LinkedHashSet   60000  23263220
# 16   add   LinkedHashSet   70000  39269267
# 17   add   LinkedHashSet   80000  44368902
# 18   add   LinkedHashSet   90000  49836783
# 19   add   LinkedHashSet  100000  53592962
# 20   add         TreeSet   10000  16327314
# ...

# %% [markdown]
# ## Вставка

# %%
dsAddHashSet=dsAdd.loc[dsAdd[' class']==' HashSet']
dsAddLinkedHashSet=dsAdd.loc[dsAdd[' class']==' LinkedHashSet']
dsAddTreeSet=dsAdd.loc[dsAdd[' class']==' TreeSet']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsAddHashSet[First], dsAddHashSet[Second] / 100, label = 'add HashSet')
plt.plot(dsAddLinkedHashSet[First], dsAddLinkedHashSet[Second] / 100, label = 'add LinkedHashSet')
plt.plot(dsAddTreeSet[First], dsAddTreeSet[Second] / 100, label = 'add TreeSet')
plt.title('Set (add)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('SetAdd.png')
pass

# %% [markdown]
# ## Contains

# %%
dsContainsHashSet=dsContains.loc[dsContains[' class']==' HashSet']
dsContainsLinkedHashSet=dsContains.loc[dsContains[' class']==' LinkedHashSet']
dsContainsTreeSet=dsContains.loc[dsContains[' class']==' TreeSet']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsContainsHashSet[First], dsContainsHashSet[Second] / 100, label = 'Contains HashSet')
plt.plot(dsContainsLinkedHashSet[First], dsContainsLinkedHashSet[Second] / 100, label = 'Contains LinkedHashSet')
plt.plot(dsContainsTreeSet[First], dsContainsTreeSet[Second] / 100, label = 'Contains TreeSet')
plt.title('Set Contains')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('SetContains.png')
pass

# %% [markdown]
# ## Remove

# %%
dsRemoveHashSet=dsRemove.loc[dsRemove[' class']==' HashSet']
dsRemoveLinkedHashSet=dsRemove.loc[dsRemove[' class']==' LinkedHashSet']
dsRemoveTreeSet=dsRemove.loc[dsRemove[' class']==' TreeSet']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsRemoveHashSet[First], dsRemoveHashSet[Second] / 100, label = 'Remove HashSet')
plt.plot(dsRemoveLinkedHashSet[First], dsRemoveLinkedHashSet[Second] / 100, label = 'Remove LinkedHashSet')
plt.plot(dsRemoveTreeSet[First], dsRemoveTreeSet[Second] / 100, label = 'Remove TreeSet')
plt.title('Set Remove')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('SetRemove.png')
pass

# %% [markdown]
# ## Амортизированная оценка

# %%
dsMixHashSet=dsMix.loc[dsMix[' class']==' HashSet']
dsMixLinkedHashSet=dsMix.loc[dsMix[' class']==' LinkedHashSet']
dsMixTreeSet=dsMix.loc[dsMix[' class']==' TreeSet']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsMixHashSet[First], dsMixHashSet[Second] / 100, label = 'Mix HashSet')
plt.plot(dsMixLinkedHashSet[First], dsMixLinkedHashSet[Second] / 100, label = 'Mix LinkedHashSet')
plt.plot(dsMixTreeSet[First], dsMixTreeSet[Second] / 100, label = 'Mix TreeSet')
plt.title('Set Mix')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('SetMix.png')
pass

# %% [markdown]
# ## Вывод
# На малом объеме данных лучше использовать HashSet, на большом LinkedHashSet. TreeSet только на данных которые должны быть упорядоченны.

# %% [markdown]
# # c. Map

# %%
df = pd.read_csv("./report_map.csv", sep=',')
print(df)
dsAdd=df.loc[df['test'] == 'add']
dsContains=df.loc[df['test'] == 'contains']
dsRemove=df.loc[df['test'] == 'remove']
dsMix=df.loc[df['test'] == 'mix']
# Out:
#     test           class       N       time
# 0    add         HashMap   10000    4258150
# 1    add         HashMap   20000    9224726
# 2    add         HashMap   30000   10958523
# 3    add         HashMap   40000   12805523
# 4    add         HashMap   50000   14916985
# 5    add         HashMap   60000   17272011
# 6    add         HashMap   70000   21441418
# 7    add         HashMap   80000   25725163
# 8    add         HashMap   90000   29762744
# 9    add         HashMap  100000   34290146
# 10   add   LinkedHashMap   10000    8490182
# 11   add   LinkedHashMap   20000   17940191
# 12   add   LinkedHashMap   30000   23588914
# 13   add   LinkedHashMap   40000   27757695
# 14   add   LinkedHashMap   50000   33022327
# 15   add   LinkedHashMap   60000   50891229
# 16   add   LinkedHashMap   70000   56520531
# 17   add   LinkedHashMap   80000   62130095
# 18   add   LinkedHashMap   90000   70825316
# 19   add   LinkedHashMap  100000   81957003
# ...

# %% [markdown]
# ## Вставка

# %%
dsAddHashMap=dsAdd.loc[dsAdd[' class']==' HashMap']
dsAddLinkedHashMap=dsAdd.loc[dsAdd[' class']==' LinkedHashMap']
dsAddTreeMap=dsAdd.loc[dsAdd[' class']==' TreeMap']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsAddHashMap[First], dsAddHashMap[Second] / 100, label = 'add HashSet')
plt.plot(dsAddLinkedHashMap[First], dsAddLinkedHashMap[Second] / 100, label = 'add LinkedHashMap')
plt.plot(dsAddTreeMap[First], dsAddTreeMap[Second] / 100, label = 'add TreeMap')
plt.title('Map (add)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MapAdd.png')
pass

# %% [markdown]
# ## ContainsKey

# %%
dsContainsHashMap=dsContains.loc[dsContains[' class']==' HashMap']
dsContainsLinkedHashMap=dsContains.loc[dsContains[' class']==' LinkedHashMap']
dsContainsTreeMap=dsContains.loc[dsContains[' class']==' TreeMap']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsContainsHashMap[First], dsContainsHashMap[Second] / 100, label = 'Contains HashMap')
plt.plot(dsContainsLinkedHashMap[First], dsContainsLinkedHashMap[Second] / 100, label = 'Contains LinkedHashMap')
plt.plot(dsContainsTreeMap[First], dsContainsTreeMap[Second] / 100, label = 'Contains TreeMap')
plt.title('Map Contains')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MapContains.png')
pass

# %% [markdown]
# ## Remove

# %%
dsRemoveHashMap=dsRemove.loc[dsRemove[' class']==' HashMap']
dsRemoveLinkedHashMap=dsRemove.loc[dsRemove[' class']==' LinkedHashMap']
dsRemoveTreeMap=dsRemove.loc[dsRemove[' class']==' TreeMap']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsRemoveHashMap[First], dsRemoveHashMap[Second] / 100, label = 'Remove HashMap')
plt.plot(dsRemoveLinkedHashMap[First], dsRemoveLinkedHashMap[Second] / 100, label = 'Remove LinkedHashMap')
plt.plot(dsRemoveTreeMap[First], dsRemoveTreeMap[Second] / 100, label = 'Remove TreeMap')
plt.title('Map Remove')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MapRemove.png')
pass

# %% [markdown]
# ## Амортизированная оценка

# %%
dsMixHashMap=dsMix.loc[dsMix[' class']==' HashMap']
dsMixLinkedHashMap=dsMix.loc[dsMix[' class']==' LinkedHashMap']
dsMixTreeMap=dsMix.loc[dsMix[' class']==' TreeMap']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsMixHashMap[First], dsMixHashMap[Second] / 100, label = 'Mix HashMap')
plt.plot(dsMixLinkedHashMap[First], dsMixLinkedHashMap[Second] / 100, label = 'Mix LinkedHashMap')
plt.plot(dsMixTreeMap[First], dsMixTreeMap[Second] / 100, label = 'Mix TreeMap')
plt.title('Map Mix')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MapMix.png')
pass

# %% [markdown]
# ## Вывод
# Аналогично множествам, HashMap для малого объёма данных, LinkedHashMap для большого, TreeMap для упорядоченных.

# %% [markdown]
# # MyLinkedList
# Реализованные структуры:
# - StupidMyLinkedList - односвязный список
# - MyLinkedList - двусвязный список

# %%
df = pd.read_csv("./report_mylinkedlist.csv", sep=',')
print(df)
dsInsert = df.loc[df['test'] == 'MyLinkedLis vs LinkedList (add)']
dsGet = df.loc[df['test'] == 'MyLinkedLis vs LinkedList (get)']
dsIndexOf = df.loc[df['test'] == 'MyLinkedLis vs LinkedList (indexOf)']
dsRemove = df.loc[df['test'] == 'MyLinkedLis vs LinkedList (remove)']
dsMix = df.loc[df['test'] == 'MyLinkedLis vs LinkedList (mix)']
# Out:
#                                    test                class       N  \
# 0       MyLinkedLis vs LinkedList (add)          MyLinkedLis   10000
# 1       MyLinkedLis vs LinkedList (add)          MyLinkedLis   20000
# 2       MyLinkedLis vs LinkedList (add)          MyLinkedLis   30000
# 3       MyLinkedLis vs LinkedList (add)          MyLinkedLis   40000
# 4       MyLinkedLis vs LinkedList (add)          MyLinkedLis   50000
# 5       MyLinkedLis vs LinkedList (add)          MyLinkedLis   60000
# 6       MyLinkedLis vs LinkedList (add)          MyLinkedLis   70000
# 7       MyLinkedLis vs LinkedList (add)          MyLinkedLis   80000
# 8       MyLinkedLis vs LinkedList (add)          MyLinkedLis   90000
# 9       MyLinkedLis vs LinkedList (add)          MyLinkedLis  100000
# 10      MyLinkedLis vs LinkedList (add)   StupidMyLinkedList   10000
# 11      MyLinkedLis vs LinkedList (add)   StupidMyLinkedList   20000
# 12      MyLinkedLis vs LinkedList (add)   StupidMyLinkedList   30000
# ...

# %% [markdown]
# ## add

# %%
df.loc[df['test'] == 'MyLinkedLis vs LinkedList (add)']
dsInsertMyLinkedList=dsInsert.loc[dsInsert[' class']==' MyLinkedLis']
dsInsertLinkedList=dsInsert.loc[dsInsert[' class']==' LinkedList']
dsInsertCachedLinkedList=dsInsert.loc[dsInsert[' class']==' circleCachedList']
dsInsertStupidMyLinkedList=dsInsert.loc[dsInsert[' class']==' StupidMyLinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsInsertMyLinkedList[First], dsInsertMyLinkedList[Second] / 100, label = 'Insert MyLinkedList')
# plt.plot(dsInsertCachedLinkedList[First], dsInsertCachedLinkedList[Second] / 100, label = 'Insert CachedLinkedList')
plt.plot(dsInsertLinkedList[First], dsInsertLinkedList[Second] / 100, label = 'Insert LinkedList')
plt.plot(dsInsertStupidMyLinkedList[First], dsInsertStupidMyLinkedList[Second] / 100, label = 'Insert StupidMyLinkedList')
plt.title('MyLinkedList vs LinkedList (add)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MylistAdd.png')
pass

# %% [markdown]
# ## get

# %%
df.loc[df['test'] == 'MyLinkedLis vs LinkedList (get)']
dsGetMyLinkedList=dsGet.loc[dsGet[' class']==' MyLinkedLis']
dsGetLinkedList=dsGet.loc[dsGet[' class']==' LinkedList']
dsGetCachedLinkedList=dsGet.loc[dsGet[' class']==' circleCachedList']
dsGetStupidMyLinkedList=dsGet.loc[dsGet[' class']==' StupidMyLinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsGetMyLinkedList[First], dsGetMyLinkedList[Second] / 100, label = 'Get MyLinkedList')
plt.plot(dsGetCachedLinkedList[First], dsGetCachedLinkedList[Second] / 100, label = 'Get CachedLinkedList')
plt.plot(dsGetLinkedList[First], dsGetLinkedList[Second] / 100, label = 'Get LinkedList')
plt.plot(dsGetStupidMyLinkedList[First], dsGetStupidMyLinkedList[Second] / 100, label = 'Get StupidMyLinkedList')


plt.title('MyLinkedList vs LinkedList (Get)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MylistGet.png')
pass

# %% [markdown]
# ## indexOf

# %%
df.loc[df['test'] == 'MyLinkedLis vs LinkedList (indexOF)']
dsIndexOfMyLinkedList=dsIndexOf.loc[dsIndexOf[' class']==' MyLinkedLis']
dsIndexOfLinkedList=dsIndexOf.loc[dsIndexOf[' class']==' LinkedList']
dsIndexOfCachedLinkedList=dsIndexOf.loc[dsIndexOf[' class']==' circleCachedList']
dsIndexOfStupidMyLinkedList=dsIndexOf.loc[dsIndexOf[' class']==' StupidMyLinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsIndexOfMyLinkedList[First], dsIndexOfMyLinkedList[Second] / 100, label = 'IndexOf MyLinkedList')
plt.plot(dsIndexOfCachedLinkedList[First], dsIndexOfCachedLinkedList[Second] / 100, label = 'IndexOf CachedLinkedList')
plt.plot(dsIndexOfLinkedList[First], dsIndexOfLinkedList[Second] / 100, label = 'IndexOf LinkedList')
plt.plot(dsIndexOfStupidMyLinkedList[First], dsIndexOfStupidMyLinkedList[Second] / 100, label = 'IndexOf StupidMyLinkedList')
plt.title('MyLinkedList vs LinkedList (IndexOf)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MylistIndexof.png')
pass

# %% [markdown]
# ## Remove

# %%
df.loc[df['test'] == 'MyLinkedLis vs LinkedList (remove)']
dsRemoveMyLinkedList=dsRemove.loc[dsRemove[' class']==' MyLinkedLis']
dsRemoveLinkedList=dsRemove.loc[dsRemove[' class']==' LinkedList']
dsRemoveCachedLinkedList=dsRemove.loc[dsRemove[' class']==' circleCachedList']
dsRemoveStupidMyLinkedList=dsRemove.loc[dsRemove[' class']==' StupidMyLinkedList']
First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsRemoveMyLinkedList[First], dsRemoveMyLinkedList[Second] / 100, label = 'Remove MyLinkedList')
# plt.plot(dsRemoveCachedLinkedList[First], dsRemoveCachedLinkedList[Second] / 100, label = 'Remove CachedLinkedList')
plt.plot(dsRemoveLinkedList[First], dsRemoveLinkedList[Second] / 100, label = 'Remove LinkedList')
plt.plot(dsRemoveStupidMyLinkedList[First], dsRemoveStupidMyLinkedList[Second] / 100, label = 'Remove StupidMyLinkedList')


plt.title('MyLinkedList vs LinkedList (Remove)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MyLinkedRemove.png')
pass

# %% [markdown]
# ## Амортизированная оценка

# %%
df.loc[df['test'] == 'MyLinkedLis vs LinkedList (mix)']
dsMixMyLinkedList=dsMix.loc[dsMix[' class']==' MyLinkedLis']
dsMixLinkedList=dsMix.loc[dsMix[' class']==' LinkedList']
dsMixCachedLinkedList=dsMix.loc[dsMix[' class']==' circleCachedList']
dsMixStupidMyLinkedList=dsMix.loc[dsMix[' class']==' StupidMyLinkedList']


First = ' N'
Second = ' time'
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(dsMixMyLinkedList[First], dsMixMyLinkedList[Second] / 100, label = 'Mix MyLinkedList')
# plt.plot(dsMixCachedLinkedList[First], dsMixCachedLinkedList[Second] / 100, label = 'Mix CachedLinkedList')
plt.plot(dsMixLinkedList[First], dsMixLinkedList[Second] / 100, label = 'Mix LinkedList')
plt.plot(dsMixStupidMyLinkedList[First], dsMixStupidMyLinkedList[Second] / 100, label = 'Mix StupidMyLinkedList')


plt.title('MyLinkedList vs LinkedList (Mix)')
plt.xlabel('Size of list (elements)')
plt.ylabel('Time')
plt.legend()
plt.savefig('MylinkedMix.png')
pass
